# %%
import random
import string
# we imported random and string as libraries
print ("Password Generator")
# Out:
# Password Generator

# %%
letters = string.ascii_letters
numbers = string.digits
symbols = string.punctuation

#An ASCII letter is any standard English alphabet character
#A digit is a single numerical symbol used to build numbers
#The system of standardized symbols and marks

print(letters)
print(numbers)
print(symbols)
# Out:
# abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ
# 0123456789
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
all_characters = letters + numbers + symbols

print(all_characters)
# Out:
# abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789!"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
length=12

# %%
password=""

# %%
random.choice(all_characters)
# Out:
# 'R'

# %%
random.choice(all_characters)
# Out:
# ','

# %%
random.choice(all_characters)
# Out:
# ';'

# %%
random.choice(all_characters)
# Out:
# 'z'

# %%
password = ""

for i in range(length):
    password = password + random.choice(all_characters)
print(password)
# Out:
# 2JkM+\Hj$!gf

# %%
import random
import string
# we imported random and string as libraries

print ("Password Generator")
letters = string.ascii_letters
numbers = string.digits
symbols = string.punctuation

#An ASCII letter is any standard English alphabet character
#A digit is a single numerical symbol used to build numbers
#The system of standardized symbols and marks

print(letters)
print(numbers)
print(symbols)

all_characters = letters + numbers + symbols

print(all_characters)

length=int(input('Passwordlength:'))
password = ""

for i in range(length):
    password = password + random.choice(all_characters)
print(password)
# Out:
# Password Generator
# abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ
# 0123456789
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~
# abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789!"#$%&'()*+,-./:;<=>?@[\]^_`{|}~
