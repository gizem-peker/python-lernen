# %%
print("Enter a player's name")
player_name=input()
# Out:
# Enter a player's name
#  Gizem

# %%
print("Enter a player's name")
player_name=input()
print("Is this player a starter?Enter \'Y\' for yes and \'N\' for no.")
player_starter=input()
print("The playaer is:")
print(player_name)
if player_starter== "Y":
    print("(Starter)")
# Out:
# Enter a player's name
#  Gregor
# Is this player a starter?Enter 'Y' for yes and 'N' for no.
#  N
# The playaer is:
# Gregor

# %%
print(player_starter)
# Out:
# N

# %%
print("Enter a number")
my_number=input()
if int(my_number)< 10:
    print("Your number is less than 10!)
          print(my_number)
          print("We are done!")
# Out:
#   File "/var/folders/v_/jm22s5zn1fv5rx_705kbt8gr0000gn/T/ipykernel_2330/2523253239.py", line 4
#     print("Your number is less than 10!)
#                                         ^
# SyntaxError: EOL while scanning string literal

# %%
print("Enter a number")
my_number=input()
# Out:
# Enter a number
#  4.56

# %%
if int(my_number)< 10:
    print("Your number is less than 10!)
          print(my_number)
          print("We are done!")
# Out:
#   File "/var/folders/v_/jm22s5zn1fv5rx_705kbt8gr0000gn/T/ipykernel_2330/4231419125.py", line 2
#     print("Your number is less than 10!)
#                                         ^
# SyntaxError: EOL while scanning string literal

# %%
if int(my_number)< 10:
    print("Your number is less than 10!)
          print(my_number)
          print("We are done!")
# Out:
#   File "/var/folders/v_/jm22s5zn1fv5rx_705kbt8gr0000gn/T/ipykernel_2330/4231419125.py", line 2
#     print("Your number is less than 10!)
#                                         ^
# SyntaxError: EOL while scanning string literal

# %%
if int(my_number)< 10:
    print("Your number is less than 10!)
# Out:
#   File "/var/folders/v_/jm22s5zn1fv5rx_705kbt8gr0000gn/T/ipykernel_2330/3143718427.py", line 2
#     print("Your number is less than 10!)
#                                         ^
# SyntaxError: EOL while scanning string literal

# %%
print("Enter a number")
my_number=input()
# Out:
# Enter a number
#  5

# %%
if int(my_number)< 10:
    print("Your number is less than 10!)
# Out:
#   File "/var/folders/v_/jm22s5zn1fv5rx_705kbt8gr0000gn/T/ipykernel_2330/3143718427.py", line 2
#     print("Your number is less than 10!)
#                                         ^
# SyntaxError: EOL while scanning string literal

# %%
if int(my_number)< 10:
    print("Your number is less than 10!")
# Out:
# Your number is less than 10!

# %%
if int(my_number)< 10:
    print("Your number is less than 10!")
          print(my_number)
          print("We are done!")
# Out:
#   File "/var/folders/v_/jm22s5zn1fv5rx_705kbt8gr0000gn/T/ipykernel_2330/1020025700.py", line 3
#     print(my_number)
#     ^
# IndentationError: unexpected indent

# %%
print(my_number)
          print("We are done!")
# Out:
#   File "/var/folders/v_/jm22s5zn1fv5rx_705kbt8gr0000gn/T/ipykernel_2330/2178463291.py", line 2
#     print("We are done!")
#     ^
# IndentationError: unexpected indent

# %%
print("Enter a number")
my_number=input()
# Out:
# Enter a number
#  5

# %%
if int(my_number)< 10:
    print("Your number is less than 10!")
# Out:
# Your number is less than 10!

# %%
print(my_number)
print("We are done!")
# Out:
# 5
# We are done!

# %%
print("Enter a number")
my_number=input()
# Out:
# Enter a number
#  6.2

# %%
if float(my_number)< 10:
    print("Your number is less than 10!")
# Out:
# Your number is less than 10!

# %%
print("Enter a number")
my_number=input()
# Out:
# Enter a number
#  12

# %%
if int(my_number)< 10:
    print("Your number is less than 10!”)
# Out:
#   File "/var/folders/v_/jm22s5zn1fv5rx_705kbt8gr0000gn/T/ipykernel_2330/4058048061.py", line 2
#     print("Your number is less than 10!”)
#                                          ^
# SyntaxError: EOL while scanning string literal

# %%
if int(my_number)< 10:
    print("Your number is less than 10!")

# %%
print("Enter a number")
my_number=input()
if int(my_number)< 10:
    print("Your number is less than 10!”)
# Out:
#   File "/var/folders/v_/jm22s5zn1fv5rx_705kbt8gr0000gn/T/ipykernel_2330/2249820498.py", line 4
#     print("Your number is less than 10!”)
#                                          ^
# SyntaxError: EOL while scanning string literal

# %%
my_number=input()
# Out:
#  12

# %%
print(my_number)
if int(my_number) >= 10:
    print("Your number is not less than 10!")
# Out:
# 12
# Your number is not less than 10!

# %%
my_number=input()
# Out:
#  3

# %%
print(my_number)
if int(my_number) >= 10:
    print("Your number is not less than 10!")
# Out:
# 3

# %%
print("Enter a number")
my_number=input()
if int(my_number)< 10:
# Out:
#   File "/var/folders/v_/jm22s5zn1fv5rx_705kbt8gr0000gn/T/ipykernel_2330/963011190.py", line 3
#     if int(my_number)< 10:
#                           ^
# IndentationError: expected an indented block

# %%
print("Enter a number")
my_number=input()
# Out:
# Enter a number
#  345678

# %%
if int(my_number)< 10:
    print("Your number is less than 10!")
else: 
    print("Your number is not less than 10!")
    print("We are done!")
# Out:
# Your number is not less than 10!
# We are done!

# %%
if int(my_number)< 10:
    print("Your number is less than 10!")
else: 
    print("Your number is not less than 10!")
    print("We are done!")
# Out:
# Your number is not less than 10!
# We are done!
