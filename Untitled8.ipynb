# %%
vorname=input('Max')
nachname=input('Mustermann')
straße=input('Musterstraße')
haus_nummer=str(input('10'))
postleitzahl=print(65185)
stadt=input('Wiesbaden')
land=input('Deutschland')
telefon_nummer=str(input('01723345674'))
e_mail_adresse=print('max_mustermann@cx.com')
# Out:
# Max
# Mustermann
# Musterstraße
# 10
# 65185
# Wiesbaden
# Deutschland
# 01723345674
# max_mustermann@cx.com

# %%
adresse=vorname+nachname+straße+haus_nummer+postleitzahl+stadt
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/v_/jm22s5zn1fv5rx_705kbt8gr0000gn/T/ipykernel_13860/2358184683.py in <module>
# ----> 1 adresse=vorname+nachname+straße+haus_nummer+postleitzahl+stadt
#
# TypeError: can only concatenate str (not "NoneType") to str

# %%
print('vorname')
# Out:
# vorname

# %% [raw]
# print(nachname)

# %%
str(vorname)
# Out:
# ''

# %%
vorname= 'Max'
nachname='Mustermann'
straße='Musterstraße'
haus_nummer='10'
postleitzahl='65185'
stadt='Wiesbaden'
land='Deutschland'
telefon_nummer='01723345674'
e_mail_adresse='max_mustermann@cx.com'

# %%
print(vorname)
# Out:
# Max

# %%
print(postleitzahl)
# Out:
# 65185

# %%
str(postleitzahl)
# Out:
# '65185'

# %%
adresse=vorname+" "+nachname+" "+straße+" "+haus_nummer+" "+postleitzahl+" "+stadt

# %%
print(adresse)
# Out:
# Max Mustermann Musterstraße 10 65185 Wiesbaden

# %%
adresse=vorname+" "+nachname+ " "+straße+" "+haus_nummer+" "+postleitzahl+" "+stadt

# %%
print(adresse)
# Out:
# Max Mustermann Musterstraße 10 65185 Wiesbaden

# %%
vorname=input('Vorname:')
# Out:
# Vorname: Max
