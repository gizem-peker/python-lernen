# %%
print('merhaba \n ben gizem')
# Out:
# merhaba
#  ben gizem

# %%
print('merhaba\nben gizem')
# Out:
# merhaba
# ben gizem

# %%
print('benim adim{}.format('gizem')')
# Out:
#   File "/var/folders/v_/jm22s5zn1fv5rx_705kbt8gr0000gn/T/ipykernel_1377/2932967389.py", line 1
#     print('benim adim{}.format('gizem')')
#                                 ^
# SyntaxError: invalid syntax

# %%
print('benim adim {}'.format('gizem')')
# Out:
#   File "/var/folders/v_/jm22s5zn1fv5rx_705kbt8gr0000gn/T/ipykernel_1377/2257983957.py", line 1
#     print('benim adim {}'.format('gizem')')
#                                            ^
# SyntaxError: EOL while scanning string literal

# %%
print('benim adim {}'.format('gizem') )
# Out:
# benim adim gizem

# %%
print ('benim adim {}, yasim{}'.format(' gizem',   33))
# Out:
# benim adim gizem, yasim33

# %%
(print('benim adim {ad}, yasim {yas}'.format(ad='gizem',yas=33))
# Out:
#   File "/var/folders/v_/jm22s5zn1fv5rx_705kbt8gr0000gn/T/ipykernel_1377/441419197.py", line 1
#     (print('benim adim {ad}, yasim {yas}'.format(ad='gizem',yas=33))
#                                                                     ^
# SyntaxError: unexpected EOF while parsing

# %%
print('benim adim {ad}, yasim {yas}'.format(ad='gizem',yas=33))
# Out:
# benim adim gizem, yasim 33
